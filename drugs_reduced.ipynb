# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#condense benefits review, comments review, and side effects review into one 
drugs = pd.read_csv("drugs_merged.csv")
drugs["benefitsReview"] = drugs["benefitsReview"].str.lower()
drugs["commentsReview"] = drugs["commentsReview"].str.lower()
drugs["sideEffectsReview"] = drugs["sideEffectsReview"].str.lower()
benefits = drugs[drugs["review"].isnul()].benefitsReview.fillna(" ")
comments = drugs[drugs["review"].isnull()].commentsReview.fillna(" ") 
side_effects = drugs[drugs["review"].isnull()].sideEffectsReview.fillna(" ")
reviews = benefits + " " + comments + " " + side_effects 
drugs.loc[drugs["review"].isnull(), "review"] = reviews 
drugs["review"]  = drugs["review"].str.lower()
drugs[["drugName", "over_counter_name", "condition", "effectiveness", "sideEffects", "price", "rating", "review", "usefulCount"]].to_csv("drugs_reduced.csv")

# %%
drugs = pd.read_csv("drugs_reduced.csv")
# Out:
# C:\Users\Jordan Fan\Anaconda3\envs\stat159\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(drugs.over_counter_name.unique())
# Out:
# 542

# %%
len(drugs[drugs.price.isnull()].over_counter_name.unique())
# Out:
# 197

# %%
drugs[~drugs.price.isnull()].shape
# Out:
# (63488, 10)

# %%
drugs.shape
# Out:
# (70108, 10)

# %%
drugs.rating.value_counts()
# Out:
# 10.0    23630
# 9.0     12960
# 8.0      8785
# 1.0      7893
# 7.0      4353
# 5.0      3109
# 6.0      2712
# 2.0      2428
# 3.0      2384
# 4.0      1854
# Name: rating, dtype: int64

# %%
drugs[drugs.price.isnull()].rating.value_counts()
# Out:
# 10.0    2086
# 9.0     1090
# 1.0      895
# 8.0      797
# 7.0      416
# 5.0      318
# 3.0      288
# 2.0      271
# 6.0      251
# 4.0      208
# Name: rating, dtype: int64

# %%
drugs.over_counter_name.value_counts(ascending = True)
# Out:
# 6.0

# %%
drugs = drugs[~drugs.price.isnull()]
drugs = drugs[~drugs["condition"].isnull()]

# %%
drugs_less_5 = drugs.over_counter_name.value_counts().index[(drugs.over_counter_name.value_counts() <= 5)]
drugs = drugs[~drugs.over_counter_name.isin(drugs_less_5)]

# %%
drugs.to_csv("drugs_reduced_reduced.csv")

# %%
drugs[~drugs.effectiveness.isnull()]
# Out:
#       Unnamed: 0           drugName  over_counter_name  \
# 0              0          enalapril          enalapril
# 3              3           prilosec           prilosec
# 4              4             lyrica             lyrica
# 5              5           propecia           propecia
# 6              6            vyvanse            vyvanse
# 8              8              xanax              xanax
# 9              9           claritin           claritin
# 10            10             flagyl             flagyl
# 11            11  dextroamphetamine  dextroamphetamine
# 12            12            sarafem            sarafem
# 13            13            latisse            latisse
# 14            14             aldara             aldara
# 16            16          neurontin          neurontin
# 18            18           klonopin           klonopin
# 19            19            dovonex            dovonex
# 20            20           protopic           protopic
# 21            21            effexor            effexor
# 24            24        lamotrigine        lamotrigine
# 25            25              rebif              rebif
# 26            26          symbicort          symbicort
# 27            27           lamictal           lamictal
# 28            28             lyrica             lyrica
# 29            29        doxycycline        doxycycline
# 30            30            vyvanse            vyvanse
# 31            31            actonel            actonel
# 32            32           provigil           provigil
# 33            33             ambien             ambien
# 34            34         wellbutrin         wellbutrin
# 35            35           propecia           propecia
# 36            36      nortriptyline      nortriptyline
# ...          ...                ...                ...
# 4095        4095        doxycycline        doxycycline
# 4097        4097            chantix            chantix
# 4099        4099        doxycycline        doxycycline
# 4101        4101         citalopram         citalopram
# 4102        4102            prempro            prempro
# 4104        4104            abilify            abilify
# 4106        4106          neurontin          neurontin
# 4107        4107            vicodin            vicodin
# 4108        4108           cymbalta           cymbalta
# 4110        4110           cymbalta           cymbalta
# 4111        4111           naproxen           naproxen
# 4112        4112          strattera          strattera
# 4113        4113              paxil              paxil
# 4114        4114           differin           differin
# 4115        4115             ambien             ambien
# 4117        4117             nexium             nexium
# 4118        4118             nexium             nexium
# 4119        4119           provigil           provigil
# 4120        4120             requip             requip
# 4121        4121              paxil              paxil
# 4124        4124           levaquin           levaquin
# 4125        4125          neurontin          neurontin
# 4126        4126           prinivil           prinivil
# 4128        4128           coumadin           coumadin
# 4129        4129           differin           differin
# 4132        4132          augmentin          augmentin
# 4133        4133            vyvanse            vyvanse
# 4134        4134            chantix            chantix
# 4136        4136            flonase            flonase
# 4140        4140            divigel            divigel
#
#                                               condition  \
# 0                management of congestive heart failure
# 3                                           acid reflux
# 4                                          fibromyalgia
# 5                                             hair loss
# 6                                                   add
# 8                                        panic disorder
# 9                                             allergies
# 10                                  bacterial vaginosis
# 11                                                  add
# 12                                           depression
# 13                                     sparse eyelashes
# 14                                          skin cancer
# 16                                       nerve disorder
# 18                         generalized anxiety disorder
# 19                                            psoriasis
# 20                                               ezcema
# 21                         panic attacks and depression
# 24                                              epilpsy
# 25                                   multiple sclerosis
# 26                                    asthma, emphysema
# 27                      bipolar disorder and depression
# 28                   fibromyalgia, failed back syndrome
# 29                                                 acne
# 30                                                 adhd
# 31                                         osteoporosis
# 32                                              fatigue
# 33                                             insomnia
# 34                                           depression
# 35                                male pattern baldness
# 36                                  a typical migraines
# ...                                                 ...
# 4095                                    chest infection
# 4097                                  tobacco addiction
# 4099                                               acne
# 4101                                         depression
# 4102                                          menopause
# 4104                                         depression
# 4106                               peripheral pain arms
# 4107                                       post-op pain
# 4108                                       fybromyalgia
# 4110                                       fibromyalgia
# 4111    costochondritis/ inflammation of the chest wall
# 4112                                                add
# 4113                                         depression
# 4114                                               acne
# 4115                                           insomnia
# 4117                  acid reflux / barrett's esophagus
# 4118                                        acid reflux
# 4119                                 multiple sclerosis
# 4120                             restless legs syndrome
# 4121                                    mild depression
# 4124                                         bronchitis
# 4125                      epilepsy, depression and pain
# 4126  doctor said my blood pressure was somewhat hig...
# 4128                                       heart murmer
# 4129                                         blackheads
# 4132                              severe abcessed tooth
# 4133                                               adhd
# 4134                                            smoking
# 4136                                   sinus congestion
# 4140                                          menopause
#
#                effectiveness                    sideEffects      price  \
# 0           Highly Effective              Mild Side Effects    0.10109
# 3       Marginally Effective              Mild Side Effects    0.61204
# 4       Marginally Effective            Severe Side Effects    3.58681
# 5                Ineffective            Severe Side Effects    2.42725
# 6           Highly Effective              Mild Side Effects    5.90802
# 8           Highly Effective                No Side Effects    1.72863
# 9                Ineffective  Extremely Severe Side Effects    0.07479
# 10    Considerably Effective          Moderate Side Effects   13.76837
# 11          Highly Effective          Moderate Side Effects    0.32491
# 12    Considerably Effective              Mild Side Effects    8.95389
# 13    Considerably Effective              Mild Side Effects   31.65457
# 14    Considerably Effective            Severe Side Effects   33.63524
# 16       6.0  i'm taking gabapentin to treat nerve disorder....          NaN
# 18       8.0  very good at relieving anxiety.  good at gener...          NaN
# 19       6.0  controlled the psoriasis, however did not redu...          NaN
# 20       8.0  cure the ezcema and it took aout teh roughest ...          NaN
# 21       9.0  reduction of panic attacks and depression to a...          NaN
# 24       9.0  fits settled down to maybe 1 a fortnight which...          NaN
# 25       6.0  reduce number of ms relapses subcutaneous inje...          NaN
# 26      10.0  i had taken pulmicort, and other inhalants, wi...          NaN
# 27       8.0  i'm feeling more grounded; highs and lows are ...          NaN
# 28       1.0  it seemed to work at first, but then the side ...          NaN
# 29       8.0  decrease in acne pustules take medication twic...          NaN
# 30       8.0  alert, awake, focused i have only been on vyva...          NaN
# 31       7.0  my  bone density's results have always been st...          NaN
# 32       7.0  i was more alert during the first part of the ...          NaN
# 33       8.0  sleeping 7-8 hours without hangover it is a go...          NaN
# 34      10.0  i have taken antidepressants for many years, a...          NaN
# 35       8.0  ostensibly this will halt or even reverse the ...          NaN
# 36       3.0  i have a-typical migraines which gives me weir...          NaN
# ...      ...                                                ...          ...
# 4095     2.0  next to none - bringing up rubbish did seem to...          NaN
# 4097     1.0  it mostly eliminated the urge to smoke, allowi...          NaN
# 4099     8.0  excellent improvement of papular pustular acne...          NaN
# 4101     6.0  i found that the drug helped with mild depress...          NaN
# 4102     5.0  hot flashes were less frequent.  libido was im...          NaN
# 4104     6.0  i've only been on it for a week but i've notic...          NaN
# 4106     7.0  reduced pain and discomfort in both arms.  cal...          NaN
# 4107     1.0  the treatment benefits of vicodin (hydrocodone...          NaN
# 4108    10.0  for severe pain and acheness i had severe pain...          NaN
# 4110     5.0  it seemed to relax me, which reduced some of t...          NaN
# 4111     1.0  none i couldn't lift anything heavy cause of t...          NaN
# 4112     3.0  strattera seemed to give me some energy and fo...          NaN
# 4113     6.0  the treatment benefits included feeling less a...          NaN
# 4114     6.0  reduced acne and refined skin texture. helped ...          NaN
# 4115     9.0  for the treatment of insomnia, this drug induc...          NaN
# 4117     8.0  pain and heartburn from extreme acid reflux is...          NaN
# 4118     8.0  reduced the acid reflux and heartburn that was...          NaN
# 4119     8.0  provigil energizes me which improves my abilit...          NaN
# 4120     9.0  requip has helped me sleep at night! no more h...          NaN
# 4121    10.0  i could see a dramatic difference in my mood w...          NaN
# 4124     1.0  i got much better in a few days. by day 3 on t...          NaN
# 4125     8.0  this medication was initially prescribed for p...          NaN
# 4126     2.0  not very many at all. my blood pressure is sti...          NaN
# 4128     4.0  reduced risk of stroke 14.5 mg daily excesive ...          NaN
# 4129     6.0  reduction in white heads however i think i sti...          NaN
# 4132     9.0  infection, swelling and pain reduction with in...          NaN
# 4133    10.0  helps me to concentrate and focus for a more p...          NaN
# 4134    10.0  when i took the medication as prescribed, if i...          NaN
# 4136     9.0  i used it for six months and it worked like a ...          NaN
# 4140    10.0  my overall mood, sense of well being, energy l...          NaN
#
# [3136 rows x 10 columns]

# %%
for i in drugs.columns:
    print(i)
    print(drugs[i].isnull().sum())
# Out:
# Unnamed: 0
# 0
# drugName
# 0
# over_counter_name
# 0
# condition
# 0
# effectiveness
# 60132
# sideEffects
# 60132
# price
# 0
# rating
# 0
# review
# 0
# usefulCount
# 3136
